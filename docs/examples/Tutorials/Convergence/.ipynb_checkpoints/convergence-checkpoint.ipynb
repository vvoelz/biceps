# %% [markdown]
# <h1 style="align: center;font-size: 18pt;">Convergence Submodule</h1>
# <hr style="height:2.5px">
#
# This tutorial shows the user how to use the `convergence submodule` within `BICePs` to determine if the MCMC sampling has converged.
#
# <hr style="height:2.5px">

# %%
import biceps
# Out:
# BICePs - Bayesian Inference of Conformational Populations, Version 2.0

# %%
# %matplotlib inline
C = biceps.Convergence(
    trajfile='../MP_Lambdas/results/traj_lambda0.00.npz',
    resultdir="./")
# Out:
# Loading trajectory file...
# ...

# %%
C.plot_traces(fname="traces.pdf", xlim=(0, 100000))
# Out:
# Plotting traces...
# Done!

# %%
C.get_autocorrelation_curves(method="exp", maxtau=5000)
# Out:
# Calculating autocorrelation ...
# Done!
# Calculating autocorrelation times...
# Done!
# Best-fit tau1 = -1209.9683663483797 +/- 671954.9897884243
# Best-fit tau1 = 14.404420569407817 +/- 0.2315352944572098
# Best-fit tau1 = 32977382.57532002 +/- -2.862148280277646e+24
# self.tau_c = [-1.20996837e+03  1.44044206e+01  3.29773826e+07]
# Plotting autocorrelation curve ...
# Done!

# %%
C.get_autocorrelation_curves(method="normal", maxtau=5000)
# Out:
# Calculating autocorrelation ...
# Done!
# Calculating autocorrelation times...
# Done!
# NOTE: Found a negative autocorrelation time...
# Plotting autocorrelation curve ...
# Done!

# %%
C.process(nblock=5, nfold=10, nround=100, savefile=False,
    plot=True, block=True, normalize=True)
# Out:
# starting calculating JSDs ...
# /Users/tuc41004/github/biceps/docs/examples/Tutorials/Convergence/biceps/convergence.py:455: RuntimeWarning: divide by zero encountered in log
#   H1 = -1.*r1/N1*np.log(r1/N1)
# /Users/tuc41004/github/biceps/docs/examples/Tutorials/Convergence/biceps/convergence.py:455: RuntimeWarning: invalid value encountered in multiply
#   H1 = -1.*r1/N1*np.log(r1/N1)
# /Users/tuc41004/github/biceps/docs/examples/Tutorials/Convergence/biceps/convergence.py:457: RuntimeWarning: divide by zero encountered in log
#   H2 = -1.*r2/N2*np.log(r2/N2)
# /Users/tuc41004/github/biceps/docs/examples/Tutorials/Convergence/biceps/convergence.py:457: RuntimeWarning: invalid value encountered in multiply
#   H2 = -1.*r2/N2*np.log(r2/N2)
# /Users/tuc41004/github/biceps/docs/examples/Tutorials/Convergence/biceps/convergence.py:459: RuntimeWarning: divide by zero encountered in log
#   H = -1.*r_total/N_total*np.log(r_total/N_total)
# ...

# %% [markdown]
# <h6 style="align: justify;font-size: 12pt"># <span style="color:red;">NOTE</span>: The following cell is for pretty notebook rendering</h6>

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../../../theme.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     #notebook { /* centers the page content */
#     padding-left:8%;
#     padding-right:9%;
#     }
#     #ipython-main-app {
#         position: relative;
#     }
#     #jupyter-main-app {
#         position: relative;
#     }
#     div.cell{
#         width:98%;
#         margin-left:4% !important;*/
#         margin-right:4%;
#     }
#     h1 {
#         font-family: "Charis SIL", Palatino, serif;
#         text-align: center;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 12pt;
#         width:99%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .output_png {
# ...
