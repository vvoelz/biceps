# %% [markdown]
# <h1 style="align: center;font-size: 18pt;">Convergence Submodule</h1>
# <hr style="height:2.5px">
#
# This tutorial shows the user how to use the `convergence submodule` within `BICePs` to determine if the MCMC sampling has converged.
#
# <hr style="height:2.5px">

# %%
import biceps
# Out:
# BICePs - Bayesian Inference of Conformational Populations, Version 2.0

# %%
C = biceps.Convergence('traj_lambda1.00.npz', nround=10)
# Out:
# Loading trajectory file...
# ...

# %%
# %matplotlib inline
C.process()
# Out:
# Calculating autocorrelation ...
# Done!
# Best-fit tau1 = 32.6858044675 +/- 0.0934586641399
# /Users/tuc41004/anaconda3/envs/py2/lib/python2.7/site-packages/biceps/convergence.py:167: RuntimeWarning: overflow encountered in exp
#   return a0 + a1*np.exp(-(x/tau1))
# Best-fit tau1 = 16.106484485 +/- 0.0223149212326
# Best-fit tau1 = 9.22976739674 +/- 0.00570436130144
# Plotting traces...
# Done!
# plotting autocorrelation curve ...
# Done!
# starting calculating JSDs ...
# /Users/tuc41004/anaconda3/envs/py2/lib/python2.7/site-packages/biceps/convergence.py:330: RuntimeWarning: divide by zero encountered in log
#   H1 = -1.*r1/N1*np.log(r1/N1)
# /Users/tuc41004/anaconda3/envs/py2/lib/python2.7/site-packages/biceps/convergence.py:330: RuntimeWarning: invalid value encountered in multiply
#   H1 = -1.*r1/N1*np.log(r1/N1)
# /Users/tuc41004/anaconda3/envs/py2/lib/python2.7/site-packages/biceps/convergence.py:332: RuntimeWarning: divide by zero encountered in log
# ...

# %% [markdown]
# <h6 style="align: justify;font-size: 12pt"># <span style="color:red;">NOTE</span>: The following cell is for pretty notebook rendering</h6>

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../../../theme.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     #notebook { /* centers the page content */
#     padding-left:8%;
#     padding-right:9%;
#     }
#     #ipython-main-app {
#         position: relative;
#     }
#     #jupyter-main-app {
#         position: relative;
#     }
#     div.cell{
#         width:98%;
#         margin-left:4% !important;*/
#         margin-right:4%;
#     }
#     h1 {
#         font-family: "Charis SIL", Palatino, serif;
#         text-align: center;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 12pt;
#         width:99%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .output_png {
# ...
